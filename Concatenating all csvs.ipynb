# %%
#trying to read one of the files: not important
import pandas as pd
f1 = pd.read_csv('Files_Directory/Assignment 1/reviews_folder/1. Za Pizza_reviews.csv', sep='|')
f1.head()
# Out:
#    Overall_rating         Review_date                       Review_title  \
# 0             4.0    October 22, 2018                "Pretty good pizza"
# 1             3.0     October 4, 2018                       "Fine Pizza"
# 2             4.0  September 24, 2018  "Awesome pizza, terrible service"
# 3             5.0   September 8, 2018                    "FABULOUS FIND"
# 4             3.0   September 4, 2018                  "Average at best"
#
#                                          Reviewer_ID  \
# 0  UID_ACA89DC68DCC059B270EC94025A6F36F-SRC_62737...
# 1  UID_D2B7224F0D86F5BC5700ED8F9F0E212B-SRC_62228...
# 2  UID_05FF5E7D615AA7335761F84D844D0D1C-SRC_61922...
# 3  UID_8E076AE10AB6261A2753E2DA6F764574-SRC_61488...
# 4  UID_9C55190B12B3E4E8623DF86B3A55AA5B-SRC_61392...
#
#                                              Reviews
# 0  "The pizza is good, but it did not blow us awa...
# 1  "This is fine pizza place, a bit heavy handed ...
# ...

# %%
#concatenating all csvs files from files_review folder into one
import shutil
import glob
import csv
#import csv files from folder
path = r'Files_Directory/Assignment 1/reviews_folder (1)/reviews_folder'
allFiles = glob.glob(path + "/*.csv")
with open('Files_Directory/Assignment 1/Total_reviews.csv', 'wb') as outfile:
    for i, fname in enumerate(allFiles):
        with open(fname, 'rb') as infile:
            if i != 0:
                infile.readline()  # Throw away header on all but first file
            # Block copy rest of file from input to output without parsing
            shutil.copyfileobj(infile, outfile)
            print(fname + " has been imported.")
# Out:
# Files_Directory/Assignment 1/reviews_folder (1)/reviews_folder\1. Za Pizza_reviews.csv has been imported.
# Files_Directory/Assignment 1/reviews_folder (1)/reviews_folder\10. Roam Artisan Burgers_reviews.csv has been imported.
# Files_Directory/Assignment 1/reviews_folder (1)/reviews_folder\1001. Mums Home of Shabu Shabu_reviews.csv has been imported.
# Files_Directory/Assignment 1/reviews_folder (1)/reviews_folder\1003. Martuni's Bar_reviews.csv has been imported.
# Files_Directory/Assignment 1/reviews_folder (1)/reviews_folder\1005. Urban Putt_reviews.csv has been imported.
# Files_Directory/Assignment 1/reviews_folder (1)/reviews_folder\1006. Chabaa Thai_reviews.csv has been imported.
# Files_Directory/Assignment 1/reviews_folder (1)/reviews_folder\1007. Caruso's at Westin St. Francis Hotel_reviews.csv has been imported.
# Files_Directory/Assignment 1/reviews_folder (1)/reviews_folder\1008. Pork Store Cafe_reviews.csv has been imported.
# ...
